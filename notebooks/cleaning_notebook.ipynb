# %% [markdown]
# # Data Cleaning Notebook
#
# Step-by-step EDA and cleaning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../data/raw/raw_hr_dataset.csv')
df.head()

# %% [markdown]
# The rest of the notebook contains EDA, cleaning steps and saving the cleaned CSV.
